# %%
# import cv2
# import time
# import rawpy
# import skimage
# import flow_vis
# import numpy as np
# import matplotlib.pyplot as plt

# from pathlib import Path
# from scipy.signal import correlate
# from scipy.signal import fftconvolve, convolve
# from scipy.interpolate import RectBivariateSpline
# from skimage.color import rgb2gray
# from skimage.filters import gaussian

from src.alignment.alignment import align_block_based, get_lk_optical_flow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 16
#       9 from pathlib import Path
#      10 # from scipy.signal import correlate
#      11 # from scipy.signal import fftconvolve, convolve
#      12 # from scipy.interpolate import RectBivariateSpline
#      13 # from skimage.color import rgb2gray
#      14 # from skimage.filters import gaussian
# ---> 16 from src.alignment.alignment import align_block_based, get_lk_optical_flow
#
# File /mnt/c/Users/dev/Documents/RAW-Multi-frame-SR/src/alignment/alignment.py:1
# ----> 1 from alignment_utils import calc_d2, downsample, extract
#       2 import cv2
#       3 import time
#
# ModuleNotFoundError: No module named 'alignment_utils'

# %%
# import cv2
import time
import rawpy
import skimage
import flow_vis
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
# from scipy.signal import correlate
# from scipy.signal import fftconvolve, convolve
# from scipy.interpolate import RectBivariateSpline
# from skimage.color import rgb2gray
# from skimage.filters import gaussian

from src.alignment.alignment import align_block_based, get_lk_optical_flow

# %%
def open_raw_images_with_downsample(dir_path: str):
    for path in Path(dir_path).glob('*.dng'):
        with rawpy.imread(str(path)) as raw:
            yield raw.postprocess(half_size=True)

# %%
imgs = list(open_raw_images_with_downsample('./imgs1'))

# %%
# up, down, left, right = 500, 1500, 400, 1200
up, down, left, right = 0, 3000, 0, 3000

# %%
img1 = imgs[0][up:down, left:right]
small1 = skimage.transform.resize(img1, (img1.shape[0] // 4, img1.shape[1] // 4), anti_aliasing=True)

img2 = imgs[5][up:down, left:right]
small2 = skimage.transform.resize(img2, (img2.shape[0] // 4, img2.shape[1] // 4), anti_aliasing=True)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 10)) 
axes[0].imshow(img1)
axes[1].imshow(img2)

# %% [markdown]
# # Block-based optical flow

# %%
base = img1.astype(np.float32)
to_align = img2.astype(np.float32)

# %%
start_time = time.time()
flow = align_block_based(base, to_align, depth=4)
print(f'Elapsed time: {time.time() - start_time:.2f} seconds')
# Out:
# processing image at depth = 1
# processing image at depth = 2
# processing image at depth = 3
# processing image at depth = 4
# Elapsed time: 16.81 seconds

# %%
flow_color = flow_vis.flow_to_color(flow, convert_to_bgr=False)
skimage.io.imshow(flow_color)

# %% [markdown]
# ## LK optical flow

# %%
flow_BB, flow_LK = get_lk_optical_flow(base, to_align, k_iters=3)
# Out:
# processing image at depth = 1
# processing image at depth = 2
# processing image at depth = 3
# processing image at depth = 4
# alignment for shape (2024, 1518, 3) taken 59.45207071304321 seconds

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 10))
axes[0].imshow(flow_vis.flow_to_color(flow_BB + flow_LK, convert_to_bgr=False))
axes[1].imshow(flow_vis.flow_to_color(flow_BB, convert_to_bgr=False))
